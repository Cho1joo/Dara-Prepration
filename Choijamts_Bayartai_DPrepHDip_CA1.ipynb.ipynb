# %% [markdown]
# # Assessment Cover Page
#
# ### Module Title: Data Preparation
#
# ### Assessment Title: CA1_DataPrep_HDip
#
# ### Student Full Name: Choijamts Bayartai
#
# ### Student Number: 2024139

# %% [markdown]
# # Importing required libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %% [markdown]
# Reading data from CSV file into dataframe named st

# %%
st = pd.read_csv('student_data.csv')

# %% [markdown]
# Showing the first 5 observations of the data dataset. By doing this we can get idea of the dataset and how we are work with this dataset

# %%
st.head()
# Out:
#   Marital status  Application mode  Application order  Course  \
# 0              1                17                  5   171.0
# 1              1                15                  1  9254.0
# 2              1                 1                  5  9070.0
# 3              1                17                  2  9773.0
# 4              2                39                  1  8014.0
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %% [markdown]
# # Characterization of dataset

# %% [markdown]
# To know how big is the dataset is we use 'shape'. It shows the total number of observations and variables. As we see total 4424 rows ,37 feautures

# %%
st.shape
# Out:
# (4424, 37)

# %% [markdown]
# Using describe method we can see overview distribution of numerical data such as count, mean, standard deviation, minimum, maximum, and various quantiles.which can be useful for initial data exploration and understanding.

# %%
st.describe()
# Out:
#        Application mode  Application order       Course  \
# count       4424.000000        4424.000000  4423.000000
# mean          18.669078           1.727848  8856.458738
# std           17.484682           1.313793  2063.763479
# min            1.000000           0.000000    33.000000
# 25%            1.000000           1.000000  9085.000000
# 50%           17.000000           1.000000  9238.000000
# 75%           39.000000           2.000000  9556.000000
# max           57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance  Previous qualification  \
# count                 4424.000000             4424.000000
# mean                     0.890823                4.577758
# std                      0.311897               10.216592
# min                      0.000000                1.000000
# 25%                      1.000000                1.000000
# 50%                      1.000000                1.000000
# ...

# %% [markdown]
# Also we can check object values

# %%
st.describe(include=object)
# Out:
#        Marital status Displaced Tuition fees up to date Age at enrollment  \
# count            4424      4424                    4423              4424
# unique              7         3                       3                47
# top                 1         1                       1                18
# freq             3918      2425                    3895              1036
#
#        Curricular units 1st sem (credited)    Target
# count                                 4424      4424
# unique                                  22         7
# top                                      0  Graduate
# freq                                  3847      2207

# %% [markdown]
# Now we are checking the data types of all variables

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   object
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4423 non-null   float64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %% [markdown]
# Now we have 3 types of data which is float65 , int64 and object.After getting info of all variables we will do check missing values

# %%
st.isnull().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            1
# Daytime/evening attendance                        0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            1
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   1
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            1
# Tuition fees up to date                           1
# Gender                                            0
# ...

# %% [markdown]
# There is not such huge missing values our dataset.As wee see some of features just single missing values now we will found out

# %% [markdown]
# Now im goin to check missing values using unique() function for each features.It is identifies an array's unique elements and provides them as a sorted array.

# %%
st['Course'].unique()
# Out:
# array([ 171., 9254., 9070., 9773., 8014., 9991., 9500., 9238., 9670.,
#        9853., 9085., 9130., 9556., 9147., 9003.,   33., 9119.,   nan])

# %%
st['Admission grade'].unique()
# Out:
# array([127.3, 142.5, 124.8, 119.6, 141.5, 114.8, 128.4, 113.1, 129.3,
#        123. , 130.6, 119.3, 130.2, 111.8, 137.1, 120.7, 137.4, 136.3,
#        124.6, 120.3, 121.8, 125.5, 114.9, 123.9, 157. , 116.4, 131. ,
#        122.1, 118.8, 150. , 130. , 138.8, 134.5, 131.4, 102.5, 128.8,
#        122.9, 113.9, 120. , 121.1, 120.4, 100.6, 121.4, 109.7, 134.1,
#        127.6, 132.4, 133.4, 126.1, 113.5, 121.3, 159.3, 129.1, 155.3,
#        139.8, 115.2, 131.9, 126. , 120.9, 128.2, 120.1, 100. , 134. ,
#        130.8, 135.8, 111.7, 132.9, 115.5, 106. , 117. , 110.2, 155.7,
#        180.4, 110. , 161. , 117.6, 128.7, 112.2, 100.8, 105. , 114. ,
#        137. , 124.9, 134.3, 111.5, 160. , 117.4, 122.2, 118.2, 106.7,
#        108.2, 107. , 136.1, 115.3, 140.4, 113.4, 118.6, 122.3, 127.9,
#        117.1, 145.3, 122.6, 128. , 123.7, 131.7, 133.2, 109.3, 113. ,
#        157.9, 112.1, 174.7, 110.1,  99.7, 121. , 119.1, 124.7, 117.2,
# ...

# %%
st['Marital status'].unique()
# Out:
# array(['1', '2', '4', '?', '3', '5', '6'], dtype=object)

# %%
st['International'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
st['Tuition fees up to date'].unique()
# Out:
# array(['1', '0', nan, '?'], dtype=object)

# %%
st['Curricular units 1st sem (credited)'].unique()
# Out:
# array(['0', '2', '3', '6', '7', '13', '4', '1', '5', '19', '11', '8',
#        '10', '9', '15', '12', '14', '18', '17', '16', '20', 'Na'],
#       dtype=object)

# %% [markdown]
# Now we wil see a few more null values that could have been concealed in that set after using "missing_value_formats" to identify the null values. Then it will change all unique values to "nan"

# %%
missing_value_formats=["n.a.","NA", "?", "n/a", "--", " ", "", "UnKnown", "Na", "NaN", "unknown"]

st=pd.read_csv("student_data.csv", na_values=missing_value_formats)

# %%
st.isnull().sum()
# Out:
# Marital status                                    1
# Application mode                                  0
# Application order                                 0
# Course                                            1
# Daytime/evening attendance                        0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            1
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   1
# Displaced                                         1
# Educational special needs                         0
# Debtor                                            1
# Tuition fees up to date                           2
# Gender                                            0
# ...

# %% [markdown]
# Double checking all unique values are changed to "nan"

# %%
st['Marital status'].unique()
# Out:
# array([ 1.,  2.,  4., nan,  3.,  5.,  6.])

# %%
st['Course'].unique()
# Out:
# array([ 171., 9254., 9070., 9773., 8014., 9991., 9500., 9238., 9670.,
#        9853., 9085., 9130., 9556., 9147., 9003.,   33., 9119.,   nan])

# %%
st["Father's qualification"].unique()
# Out:
# array([12.,  3., 37., 38.,  1., 19.,  5.,  4., 34.,  2., 39., 11.,  9.,
#        nan, 36., 26., 40., 14., 20., 35., 41., 22., 13., 29., 43., 18.,
#        42., 10.,  6., 30., 25., 44., 33., 27., 31.])

# %%
st['Tuition fees up to date'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
st['Age at enrollment'].unique()
# Out:
# array([20., 19., 45., 50., 18., 22., 21., 34., 37., 43., 55., 39., 29.,
#        24., 27., 23., 26., 33., 35., 25., 44., 36., 47., 28., 38., nan,
#        30., 31., 32., 40., 42., 48., 49., 46., 41., 70., 60., 53., 51.,
#        52., 54., 61., 58., 59., 17., 57., 62.])

# %%
st['International'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
st['Curricular units 1st sem (credited)'].unique()
# Out:
# array([ 0.,  2.,  3.,  6.,  7., 13.,  4.,  1.,  5., 19., 11.,  8., 10.,
#         9., 15., 12., 14., 18., 17., 16., 20., nan])

# %%
st['Curricular units 1st sem (without evaluations)'].unique()
# Out:
# array([ 0,  1,  2,  4,  3,  6, 12, 10,  7,  5,  8])

# %%
st['Curricular units 2nd sem (enrolled)'].unique()
# Out:
# array([ 0.,  6.,  5.,  8.,  7., 11., 12.,  9., 13., 19.,  3., 10.,  4.,
#        nan, 17.,  2.,  1., 14., 15., 16., 23., 18., 21.])

# %%
pd.isnull(st).sum().sum()
# Out:
# 14

# %% [markdown]
# Now we have total 14 null values our dataset

# %%
st_new = st.dropna(axis=0)

# %% [markdown]
# Next, I used ".dropna(axis=0) axis = observations" to remove any null values.

# %%
print(st.isnull().sum())
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# ...

# %%
pd.isnull(st).sum().sum()
# Out:
# 0

# %% [markdown]
# This function will check all null values in whole dataset "isnull(st).sum().sum()". Result we have 0 null value left which mean we handled missing values

# %% [markdown]
# I started modifying the features below to intergers utilizing the data dictionary after seeing that some of the features in my data collection were appearing as "Float" values.astype (integer)

# %%
columns_to_convert = ['Marital status','Course',"Father's qualification",'Displaced','Debtor','Tuition fees up to date','Age at enrollment','International','Curricular units 1st sem (credited)','Curricular units 1st sem (grade)','Curricular units 2nd sem (enrolled)','Curricular units 2nd sem (grade)'] 
st[columns_to_convert] = st[columns_to_convert].astype(int)
# Out:
# /var/folders/5v/q8q6sn_12l90z15mtcb4xpy00000gn/T/ipykernel_26581/2786704775.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st[columns_to_convert] = st[columns_to_convert].astype(int)

# %%
st.dtypes
# Out:
# Marital status                                      int64
# Application mode                                    int64
# Application order                                   int64
# Course                                              int64
# Daytime/evening attendance                          int64
# Previous qualification                              int64
# Previous qualification (grade)                    float64
# Nacionality                                         int64
# Mother's qualification                              int64
# Father's qualification                              int64
# Mother's occupation                                 int64
# Father's occupation                                 int64
# Admission grade                                   float64
# Displaced                                           int64
# Educational special needs                           int64
# Debtor                                              int64
# ...

# %% [markdown]
# The whole set of features in the proper data dictionary kinds is shown below.

# %% [markdown]
# # Misspelled values correct

# %% [markdown]
# Our Target feature we can say Independ variable contains some same words then i replaced corret

# %%
st["Target"]=st["Target"].replace({"Grad":"Graduate", "graduate":"Graduate", "Drop":"Dropout", "dropout":"Dropout"})

# %%
st['Target'].unique()
# Out:
# array([3, 1, 2])

# %%
st['Target'] = st['Target'].replace('Dropout', 3)
st['Target'] = st['Target'].replace('Graduate', 1)
st['Target'] = st['Target'].replace('Enrolled', 2)

# %%
st['Target'].unique()
# Out:
# array([ 0.0897826 ,  0.22203845, -0.09019718, -0.03360585, -0.07501585,
#         0.0556931 , -0.10338941,  0.01607194,  0.04280815,  0.00214498,
#         0.00565689,  0.00197985, -0.12027615, -0.11412984,  0.00734523,
#         0.24147288, -0.40927114,  0.2299538 , -0.29729522,  0.24372668,
#        -0.00263397, -0.04838261, -0.15607304, -0.04497308, -0.52948948,
#        -0.47995745,  0.0690882 , -0.05405624, -0.17600738, -0.094086  ,
#        -0.62451972, -0.56332042,  0.09399673, -0.00763606,  0.02690145,
#        -0.04451475,  1.        ])

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Detecting Outliers
#
# There are certain aspects that don't fit neatly into the "box." We call these outliers.

# %%
sns.boxplot(x = st['Course'])
# Out:
# <Axes: xlabel='Course'>

# %%
sns.boxplot(x = st['Nacionality'])
# Out:
# <Axes: xlabel='Nacionality'>

# %% [markdown]
# This method will eliminate the MOST outliers, but typically not all of them; some will still be there, but they will have shrunk in importance relative to the entire analysis.Then i just left outliers.

# %% [markdown]
# One kind of visualization that helps us determine the dependent variables or the connection between the characteristics is the heat map.

# %%
plt.figure(figsize=(20,10))
st= st.corr()
sns.heatmap(st,annot=True, fmt=".2f", cmap='coolwarm',)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Target', data=st)
plt.title('Distribution of Target Categories ')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(13, 5))
sns.countplot(x='Age at enrollment', data=st)
plt.title('Distribution of Age Categories ')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(15, 5))
sns.countplot(x='Course', data=st)
plt.title('Distribution of Course Categories ')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # PCA
# ## Curse of Dimensionality

# %%
from sklearn.decomposition import PCA
import numpy as np
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC

# %% [markdown]
# First of all we need to import all the libaries.

# %% [markdown]
# As wee see our Depented variable type was categorical variable (object) then i used replace method change variables to numbers

# %%
st.head()
# Out:
#                             Marital status  Application mode  \
# Marital status                    1.000000          0.263369
# Application mode                  0.263369          1.000000
# Application order                -0.125811         -0.286268
# Course                            0.045912          0.062915
# Daytime/evening attendance       -0.273621         -0.302744
#
#                             Application order    Course  \
# Marital status                      -0.125811  0.045912
# Application mode                    -0.286268  0.062915
# Application order                    1.000000  0.060595
# Course                               0.060595  1.000000
# Daytime/evening attendance           0.158544 -0.042557
#
#                             Daytime/evening attendance  \
# Marital status                               -0.273621
# Application mode                             -0.302744
# Application order                             0.158544
# ...

# %%
print(pd.isnull(st).sum().sum())
# Out:
# 0

# %% [markdown]
# Doubel checking missing values before doing PCA.
#
# We need drop our depentend variable.
# Then we fit to extract varience

# %%
st_no_label = st.drop(st["Target"])
pca = PCA().fit(st_no_label) 
plt.plot(np.cumsum(pca.explained_variance_ratio_)) 
plt.xlabel('number of components') 
plt.ylabel('cumulative explained variance');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 st_no_label = st.drop(st["Target"])
#       2 pca = PCA().fit(st_no_label)
#       3 plt.plot(np.cumsum(pca.explained_variance_ratio_))
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
# ...

# %% [markdown]
# This graph tells us how many components you need to create

# %%
pca = PCA(10)
projected = pca.fit_transform(st_no_label)

# %% [markdown]
# I created 10 features

# %%
projected.shape
# Out:
# (4408, 10)

# %%
st_pca = pd.DataFrame(projected, columns = ['C1','C2','C3','C4','C5','C6','C7','C8','C9','C10'])

# %%
st_pca.head()
# Out:
#             C1        C2         C3         C4         C5         C6  \
# 0  8690.274464 -0.922907  -1.108609  -6.136478 -15.232326   6.810633
# 1   847.221538 -0.159337 -36.349744  -0.562020  -7.470535   3.680733
# 2 -1129.783126 -2.333524 -36.969577   6.404054  -5.833109   1.074957
# 3  -638.737729 -4.303563   4.917857 -14.283264  18.192420 -11.711816
# 4  -392.747113 -1.438349 -20.144098 -21.707088  -6.630309   1.588890
#
#           C7         C8         C9       C10
# 0   3.570742   5.095498  -6.725280 -2.498023
# 1  22.375142  27.998539   3.621292  1.921493
# 2  -1.741409  -8.757041  -0.178683  2.091532
# 3  -2.677225  -4.139244   3.825283 -1.260518
# 4  -1.497508   1.960231 -13.867854  1.827800

# %%
st_pca["Target"] = st["Target"]

# %%
st_pca.head()
# Out:
#             C1        C2         C3         C4         C5         C6  \
# 0  8690.274464 -0.922907  -1.108609  -6.136478 -15.232326   6.810633
# 1   847.221538 -0.159337 -36.349744  -0.562020  -7.470535   3.680733
# 2 -1129.783126 -2.333524 -36.969577   6.404054  -5.833109   1.074957
# 3  -638.737729 -4.303563   4.917857 -14.283264  18.192420 -11.711816
# 4  -392.747113 -1.438349 -20.144098 -21.707088  -6.630309   1.588890
#
#           C7         C8         C9       C10  Target
# 0   3.570742   5.095498  -6.725280 -2.498023     NaN
# 1  22.375142  27.998539   3.621292  1.921493     NaN
# 2  -1.741409  -8.757041  -0.178683  2.091532     NaN
# 3  -2.677225  -4.139244   3.825283 -1.260518     NaN
# 4  -1.497508   1.960231 -13.867854  1.827800     NaN

# %%
st_array = st_pca.values

# %% [markdown]
# Now im going to trainset based on features that i created

# %%
from sklearn.model_selection import train_test_split
X = st_array.iloc[:, 0:10]  # Adjust based on the actual number of columns minus one
y = st_array.iloc[:,10] 
X_train, X_validation, Y_train, Y_validation = train_test_split(X, y, test_size=0.20, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[139], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X = st_array.iloc[:, 0:10]  # Adjust based on the actual number of columns minus one
#       3 y = st_array.iloc[:,10]
#       4 X_train, X_validation, Y_train, Y_validation = train_test_split(X, y, test_size=0.20, random_state=1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
print(pd.isnull(st_array).sum().sum())
# Out:
# 4408

# %% [markdown]
# I used 6 diffrent machine learning algorthims

# %%
models = []
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(gamma='auto')))

# %%
results = []
names = []
for name, model in models:
	kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
	cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy')
	results.append(cv_results)
	names.append(name)
	print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[132], line 5
#       3 for name, model in models:
#       4 	kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
# ----> 5 	cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy')
#       6 	results.append(cv_results)
#       7 	names.append(name)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:515, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     512 # To ensure multimetric format is not supported
#     513 scorer = check_scoring(estimator, scoring=scoring)
# --> 515 cv_results = cross_validate(
#     516     estimator=estimator,
#     517     X=X,
#     518     y=y,
#     519     groups=groups,
#     520     scoring={"score": scorer},
#     521     cv=cv,
# ...

# %%
pyplot.boxplot(results, labels=names)
pyplot.title('Algorithm Comparison')
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 pyplot.boxplot(results, labels=names)
#       2 pyplot.title('Algorithm Comparison')
#       3 pyplot.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:2836, in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, data)
#    2804 @_copy_docstring_and_deprecators(Axes.boxplot)
#    2805 def boxplot(
#    2806     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    2834     data=None,
#    2835 ) -> dict[str, Any]:
# -> 2836     return gca().boxplot(
#    2837         x,
#    2838         notch=notch,
#    2839         sym=sym,
# ...

# %% [markdown]
# Highest accuracy is LogisticRegression

# %%
model = LogisticRegression(solver='liblinear', multi_class='ovr')
model.fit(X_train, Y_train)
predictions = model.predict(X_validation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[128], line 2
#       1 model = LogisticRegression(solver='liblinear', multi_class='ovr')
# ----> 2 model.fit(X_train, Y_train)
#       3 predictions = model.predict(X_validation)
#
# NameError: name 'X_train' is not defined

# %%
print(accuracy_score(Y_validation, predictions))
print(confusion_matrix(Y_validation, predictions))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 print(accuracy_score(Y_validation, predictions))
#       2 print(confusion_matrix(Y_validation, predictions))
#
# NameError: name 'Y_validation' is not defined
